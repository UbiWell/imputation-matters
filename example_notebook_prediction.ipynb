# %%
from utils import Utils
from imputation import Imputation
# Out:
# /home/sohini/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 2025-11-22 14:44:02.709595: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-11-22 14:44:02.709632: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Load the data

# %%
# give your data's specifics instead

algo="dl_feat"
category = "W"
dataset_number = 1
folder_path="/mnt/hdd/sohini-globem-work/GLOBEM/"

u = Utils(folder_path=folder_path, algo=algo, category = category, dataset_number = dataset_number)

rapids, rapids_subset, date_map, index_to_dates, users, user_to_id = u.load_and_preprocess()
# Out:
# Dataset length: 14260
# Number of features: 54

# %%
df_percentages = u.get_not_null_percentages()
# Out:
# f_wifi has ≤ 1 column, skipping.

# %% [markdown]
# ### Impute the data

# %%
i = Imputation(rapids, rapids_subset, users, index_to_dates, algo = algo)

# %%
sknn_df = i.simple_knn()
# mice_df = i.mice()
# Out:
# 100%|█████████████████████████████████████████| 155/155 [00:15<00:00,  9.95it/s]

# %% [markdown]
# ### Save the data

# %%
imputed_data_file_path = f"data_current/INS-{category}-current_{dataset_number}/FeatureData/imputed_data_testing_code.csv"

sknn_df.to_csv(folder_path+imputed_data_file_path)

# %% [markdown]
# ### To run the GLOBEM pipeline with imputed datasets, make the following updates inside the GLOBEM directory:
#
# --> In data_loader/data_loader_ml.py, update the file_name variable to point to the appropriate imputed dataset file.
#
# --> In the data directory, delete the data generated from the previous run before starting a new one.
#
# --> In the evaluation_output directory, rename the folder from the latest run to prevent the results from being overwritten.
